# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.flipkart.com/search?q=shoes&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&as-pos=2&as-type=TRENDING&suggestionId=shoes&requestId=28f14ae9-20ae-422c-9cfa-37528bdecb3b&page=1"
r =  requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text,'lxml')
print (soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
for i in range(1,10):
    url = "https://www.flipkart.com/search?q=shoes&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&as-pos=2&as-type=TRENDING&suggestionId=shoes&requestId=28f14ae9-20ae-422c-9cfa-37528bdecb3b&page="+str(i)
    r =  requests.get(url)
    print(r)
    
    soup = BeautifulSoup(r.text,'lxml')
    
    np = soup.find("a",class_ ="_1LKTO3").get("href")
    cnp = "https://www.flipkart.com/" + np
    print(cnp)
# Out:
# <Response [200]>
# https://www.flipkart.com//search?q=shoes&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&as-pos=2&as-type=TRENDING&suggestionId=shoes&requestId=28f14ae9-20ae-422c-9cfa-37528bdecb3b&page=2
# <Response [200]>
# https://www.flipkart.com//search?q=shoes&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&as-pos=2&as-type=TRENDING&suggestionId=shoes&requestId=28f14ae9-20ae-422c-9cfa-37528bdecb3b&page=1
# <Response [200]>
# https://www.flipkart.com//search?q=shoes&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&as-pos=2&as-type=TRENDING&suggestionId=shoes&requestId=28f14ae9-20ae-422c-9cfa-37528bdecb3b&page=2
# <Response [200]>
# ...

# %%
names = soup.find_all("div",class_ = "_2WkVRV")
print(names)
# Out:
# [<div class="_2WkVRV">aadi</div>, <div class="_2WkVRV">WAAN</div>, <div class="_2WkVRV">HOTSTYLE</div>, <div class="_2WkVRV">BRUTON</div>, <div class="_2WkVRV">asian</div>, <div class="_2WkVRV">aadi</div>, <div class="_2WkVRV">jaipur trendcraft</div>, <div class="_2WkVRV">WHITE WALKERS</div>, <div class="_2WkVRV">aadi</div>, <div class="_2WkVRV">AJANTA</div>, <div class="_2WkVRV">aadi</div>, <div class="_2WkVRV">WAAN</div>, <div class="_2WkVRV">aadi</div>, <div class="_2WkVRV">AJANTA</div>, <div class="_2WkVRV">aadi</div>, <div class="_2WkVRV">AJANTA</div>, <div class="_2WkVRV">Nobelite</div>, <div class="_2WkVRV">RapidBox</div>, <div class="_2WkVRV">Beyond Retail</div>, <div class="_2WkVRV">asian</div>, <div class="_2WkVRV">ATOM</div>, <div class="_2WkVRV">Arivo</div>, <div class="_2WkVRV">aadi</div>, <div class="_2WkVRV">Kraasa</div>, <div class="_2WkVRV">Nobelite</div>, <div class="_2WkVRV">AJANTA</div>, <div class="_2WkVRV">aadi</div>, <div class="_2WkVRV">RED TAPE</div>, <div cl
# ...

# %%
Product_name = []

names = soup.find_all("div",class_ = "_2WkVRV")

for i in names:
    name = i.text
    Product_name.append(name)
    
print(Product_name)
print(len(Product_name))
# Out:
# ['aadi', 'RapidBox', 'ADIDAS', 'Sparx', 'BRUTON', 'asian', 'CAMPUS', 'ATOM', 'Vellinto', 'BIRDE', 'asian', 'aadi', 'asian', 'HOTSTYLE', 'HRX by Hrithik Roshan', 'asian', 'RED TAPE', 'aadi', 'BRUTON', 'AJANTA', 'RED TAPE', 'Nobelite', 'WAAN', 'U.S. POLO ASSN.', 'HRX by Hrithik Roshan', 'HRX by Hrithik Roshan', 'RED TAPE', 'aadi', 'HRX by Hrithik Roshan', 'CAMPUS', 'RapidBox', "K' Footlance", 'asian', 'Sparx', 'Xtoon', 'Golazo', 'kardam&sons', 'kardam&sons', 'JQR', 'asian']
# 40

# %%
Product_price = []

names = soup.find_all("div",class_ = "_3I9_wc")

for i in names:
    name = i.text
    Product_price.append(name)
    
print(Product_price)
print(len(Product_price))
# Out:
# ['₹1,999', '₹999', '₹2,999', '₹1,099', '₹2,499', '₹1,499', '₹1,899', '₹3,295', '₹1,299', '₹999', '₹1,699', '₹1,999', '₹2,299', '₹1,998', '₹3,499', '₹1,299', '₹6,899', '₹999', '₹2,499', '₹699', '₹6,799', '₹1,425', '₹1,999', '₹2,999', '₹3,699', '₹3,699', '₹6,899', '₹999', '₹3,499', '₹899', '₹999', '₹999', '₹999', '₹1,249', '₹1,499', '₹799', '₹1,299', '₹1,999', '₹1,299', '₹1,299']
# 40

# %%
Product_offer = []

names = soup.find_all("div",class_ = "_3Ay6Sb")

for i in names:
    name = i.text
    Product_offer.append(name)
    
print(Product_offer)
print(len(Product_offer))
# Out:
# ['80% off', '44% off', '52% off', '25% off', '84% off', '53% off', '27% off', '57% off', '55% off', '70% off', '57% off', '80% off', '45% off', '76% off', '70% off', '53% off', '80% off', '72% off', '84% off', '57% off', '80% off', '80% off', '80% off', '55% off', '71% off', '71% off', '80% off', '70% off', '73% off', '23% off', '44% off', '55% off', '55% off', '40% off', '74% off', '33% off', '69% off', '80% off', '30% off', '59% off', '55% off', '33% off', '57% off', '44% off', '80% off']
# 45

# %%
Product_desc = []

names = soup.find_all("div",class_ = "_1AtVbE col-12-12")

for i in names:
    name = i.text
    Product_desc.append(name)
    
print(Product_desc)
print(len(Product_desc))
# Out:
# ["FiltersCATEGORIESFootwearWomen's FootwearKids' & Infant FootwearMen's FootwearGender?Price........Min₹500₹500₹1000₹1500₹2000₹3000to₹500₹500₹1000₹1500₹2000₹3000₹3000+BrandaadiADIDASAllen SollyBataBRUTONBubblegummers2713 MORECustomer Ratings4★ & above3★ & aboveColorBeigeBlackBlueBronzeBrownBurgundy26 MOREDiscount30% or more40% or more50% or more60% or more70% or moreOffersBuy More, Save MoreNo Cost EMISpecial PriceAvailability", 'AdCurrently unavailableaadiMesh| Ultralightweight| Premiun| Comfort| Summer Tendy|...₹299₹99970% offFree deliveryDaily SaverAdWAANCasual Premium Ankle Length Black Denim Boots Canvas Sh...₹399₹2,49984% offFree deliveryLowest price since launchHOTSTYLETrendy & Stylish Running Shoes For Men₹199₹99980% offFree delivery by TodayHot DealBRUTONModern Trendy Shoes Sneakers For Men₹249₹1,29980% offFree delivery by TodayHot Deal', "asianNexon-13 White Sports,Walking,Training,Gym,Stylish, Run...₹609₹1,19949% offFree delivery by TodayaadiSynthetic| Lightweight| Premiun
# ...

# %%
#amazon

from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com/" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    #amazon_df['title'].replace('', np.nan, inplace=True)
    #amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)
    
print(amazon_df)
# Out:
# Empty DataFrame
# Columns: [title, price, rating, reviews, availability]
# Index: []
# Empty DataFrame
# Columns: [title, price, rating, reviews, availability]
# Index: []

# %%
amazon_df
# Out:
# Empty DataFrame
# Columns: [title, price, rating, reviews, availability]
# Index: []
